# %%
import xarray as xr
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#df pour DataFrame
print(os.getcwd())
df = pd.read_excel('/home/turpinli/Mera_SMB/AnnualMB_Mera_09_10.xlsx', header=1) #pandas permet ici de lire les fichiers .xlsx et prenant les colonnes à partir de la 2ème ligne
print(df.head())
print(df.columns)
print(df.dtypes) #vérifie le type de chaque colonne (on veut float/int)
#df.plot(x='x',y='y')
# Out:
# /home/turpinli/MyPythonLibrary/stageSMB
#   #station Easting_start Northing_start Altitude_start           Date_start  \
# 0      NaN             m              m              m           dd/mm/yyyy
# 1    10_07    489089.335     3068069.16       5101.276  2009-11-01 00:00:00
# 2    11_07        489055        3068694           5231  2009-11-01 00:00:00
# 3    12_07        489231        3068489           5238  2009-11-01 00:00:00
# 4    17_07    489462.501    3067711.726       5346.543  2009-10-31 00:00:00
#
#    Quality_coordinates Easting_end Northing_end Altitude_end  \
# 0                  NaN           m            m            m
# 1                  1.0   489087.77   3068069.51     5097.628
# 2                  0.0  489055.419  3068694.323     5231.108
# 3                  0.0  489231.335  3068489.175     5237.984
# 4                  1.0  489462.214  3067711.688     5344.629
#
#               Date_end  Quality_coordinates.1 Mass balance (Nov09-Nov10)  \
# 0           dd/mm/yyyy                    NaN  m water equivalent (w.e.)
# 1  2010-11-09 00:00:00                    1.0                    -2.6428
# 2  2010-11-09 00:00:00                    1.0                  -2.563171
# 3  2010-11-09 00:00:00                    1.0                     -1.991
# 4  2010-11-09 00:00:00                    1.0                    -1.5739
#
#    Unnamed: 12
# 0          NaN
# 1  Mera branch
# 2  Mera branch
# 3  Mera branch
# 4  Mera branch
# Index(['#station', 'Easting_start', 'Northing_start', 'Altitude_start',
#        'Date_start', 'Quality_coordinates', 'Easting_end', 'Northing_end',
#        'Altitude_end', 'Date_end', 'Quality_coordinates.1',
#        'Mass balance (Nov09-Nov10)', 'Unnamed: 12'],
#       dtype='object')
# #station                       object
# Easting_start                  object
# Northing_start                 object
# Altitude_start                 object
# Date_start                     object
# Quality_coordinates           float64
# Easting_end                    object
# Northing_end                   object
# Altitude_end                   object
# Date_end                       object
# Quality_coordinates.1         float64
# Mass balance (Nov09-Nov10)     object
# Unnamed: 12                    object
# dtype: object

# %%
df["Mass balance (Nov09-Nov10)"] = pd.to_numeric(df["Mass balance (Nov09-Nov10)"], errors="coerce") # Force la colonne à prendre la forme d'un nombre (car unité en haut de colonne)
df["Altitude_start"] = pd.to_numeric(df["Altitude_start"], errors="coerce") # Coerce donne NaN si la valeur n'est pas convertible en nombre

df = df.dropna(subset=["Altitude_start","Mass balance (Nov09-Nov10)"]) # Supprime les NaN dans les colonnes

df_accu = df[df["#station"].str.startswith("A")] # Regarde et garde les lignes où la colone commence par A au sein de Station
df_ablation = df[~df["#station"].str.startswith("A")] # Le ~ est la condition "not" --> Tout ce qui ne contient pas A

#Accumulation
x_accu = df_accu["Mass balance (Nov09-Nov10)"]
y_accu = df_accu["Altitude_start"]

plt.plot(x_accu,y_accu, linestyle="", marker="o",color='b')
res = stats.linregress(x_accu, y_accu) # Régression linéaire sur les deux séries de données
# La régression linéaire contient naturellement des informations comme slope = pente de regression / intercept = ordonnée à l'origine / rvalue = coeff de corrélation / pvalue
plt.plot(x_accu,res.intercept+res.slope*x_accu, 'b', label=f"R²: {res.rvalue**2:.6f}") # \np-value: {res.pvalue:.6g}") # Trace x par y =ax+b=slope*x+intercept)

#Ablation
x_ablation = df_ablation["Mass balance (Nov09-Nov10)"]
y_ablation = df_ablation["Altitude_start"]

plt.plot(x_ablation,y_ablation, linestyle="", marker="o", color='c')
res = stats.linregress(x_ablation, y_ablation) # Régression linéaire sur les deux séries de données
plt.plot(x_ablation,res.intercept+res.slope*x_ablation, 'c', label=f"R²: {res.rvalue**2:.6f}") # \np-value: {res.pvalue:.6g}") # Trace x par y =ax+b=slope*x+intercept)


plt.xlabel("Mass balance (m w.e)")
plt.ylabel("Altitude (m)")
plt.legend()
plt.show()

# %%
print(x_accu)
print(x_ablation)
